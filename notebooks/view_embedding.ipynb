# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
import matplotlib.pyplot as plt

# %%
READ_DIR = "../data/processed"

FILENAME = "twitter_airline_sentiment_cleaned_emoji_urls_html_symbols@#_quotes_currency_whitespace"

EMBEDDING_MPNET = "twitter_airline_sentiment_cleaned_emoji_urls_html_symbols@#_quotes_currency_whitespace_all-mpnet-base-v2.npy"

EMBEDDING_TWHINBERT = "twitter_airline_sentiment_cleaned_emoji_urls_html_symbols@#_quotes_currency_whitespace_twhin-bert-base.npy"

# %%
# Load embeddings
embeddings_mpnet = np.load(f"{READ_DIR}/{EMBEDDING_MPNET}")
embeddings_twhinbert = np.load(f"{READ_DIR}/{EMBEDDING_TWHINBERT}")

# %%
# Load text data
df = pd.read_csv(f"{READ_DIR}/{FILENAME}.csv")

# %% [markdown]
# ### Some MPNET embeddings:

# %%
i_start, i_end = 30, 60
sentences = embeddings_mpnet[i_start: i_end]

cs = cosine_similarity(sentences)

fig, ax = plt.subplots(1, 1, figsize=(8, 8))

labels = [f"Sentence {i}" for i in range(i_start, i_end)]

sns.heatmap(cs, xticklabels=labels, yticklabels=labels, ax=ax, square=True)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=8)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=8);

# %% [markdown]
# #### Compare similar tweets:

# %%
print(df["clean_text"].iloc[43])
print(df["clean_text"].iloc[53])
print()
print(df["clean_text"].iloc[50])
print(df["clean_text"].iloc[52])
# Out:
# are flights leaving Dallas for Seattle on time Feb 24?
# Will flights be leaving Dallas for LA on February 24th?
#
# Julie Andrews all the way though was very impressive! NO to
# Julie Andrews. Hands down.

# %% [markdown]
# ### Some twhinbert embeddings:

# %%
i_start, i_end = 30, 60
sentences = embeddings_twhinbert[i_start: i_end]

cs = cosine_similarity(sentences)

fig, ax = plt.subplots(1, 1, figsize=(8, 8))

labels = [f"Sentence {i}" for i in range(i_start, i_end)]

sns.heatmap(cs, xticklabels=labels, yticklabels=labels, ax=ax, square=True)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=8)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=8);
